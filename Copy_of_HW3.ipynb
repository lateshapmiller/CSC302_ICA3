# %% [markdown]
# <a href="https://colab.research.google.com/github/lateshapmiller/CSC302_LM/blob/main/Copy_of_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Please see examples we did in class. Questions are just variations of what we did earlier.

# %% [markdown]
# **Q1**. Please read WorldCupMatches.csv to a data frame to proceed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Q2** Using seaborn's displot draw density curves to show the distributions of Home Team Goals for every year.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

world_cup_matches = pd.read_csv('/content/drive/MyDrive/DATA/WorldCupMatches.csv')

plt.figure(figsize=(16, 8))
sns.displot(data=world_cup_matches, x="Home Team Goals", hue="Year", kind="kde", height=8, aspect=1.5, palette="tab10", legend=False)
plt.title('Density Curves of Home Team Goals for Each Year')
plt.xlabel('Home Team Goals')
plt.ylabel('Density')
plt.legend(title='Year', labels=world_cup_matches['Year'].unique())
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Q3** Draw violin plots to summarize Home Team Goals distributions for each year by using seaborn. Notice that labels are really cluttered. Then please refer to the earlier notebooks to have labels to appear on only select years which end with 0. You can use ax handle to call ax.set_xticklables(labels) for the labels your prepared.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
file_path = '/content/drive/MyDrive/DATA/WorldCupMatches.csv'
WorldCupMatches = pd.read_csv('/content/drive/MyDrive/DATA/WorldCupMatches.csv')

# Prepare a list of labels for years ending in 0
years_ending_in_0 = world_cup_matches['Year'].unique()
years_ending_in_0 = [str(year) for year in years_ending_in_0 if year % 10 == 0]

# Draw violin plots
plt.figure(figsize=(16, 8))
ax = sns.violinplot(x="Year", y="Home Team Goals", data=WorldCupMatches)
ax.set_title('Violin Plots of Home Team Goals for Each Year')
ax.set_xlabel('Year')
ax.set_ylabel('Home Team Goals')

# Adjust the xticks to show only for the years ending in 0
xticks = ax.get_xticks()
xtick_labels = [label.get_text() for label in ax.get_xticklabels()]
selected_xtick_labels = [label if label in years_ending_in_0 else '' for label in xtick_labels]

ax.set_xticks(xticks)
ax.set_xticklabels(selected_xtick_labels)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Q4** Please install joypy. Then visualize distributions for Home Team Goals and Away Team Goals' for each year. Once you visualize, please add  plt.style.use('seaborn-white') to see how colors change in your second run. Please also add the legend which you can find from the function prototype.

# %%
# !pip install joypy

# %%
import joypy as jp

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
file_path = '/content/drive/MyDrive/DATA/WorldCupMatches.csv'

# Prepare a list of labels for years ending in 0
years_ending_in_0 = WorldCupMatches['Year'].unique()
years_ending_in_0 = [str(year) for year in years_ending_in_0 if year % 10 == 0]

# Visualize distributions for Home Team Goals
plt.figure(figsize=(16, 8))
ax = sns.violinplot(x="Year", y="Home Team Goals", data=WorldCupMatches)
ax.set_title('Violin Plots of Home Team Goals for Each Year')
ax.set_xlabel('Year')
ax.set_ylabel('Home Team Goals')

# Adjust the xticks to show only for the years ending in 0
xticks = ax.get_xticks()
xtick_labels = [label.get_text() for label in ax.get_xticklabels()]
selected_xtick_labels = [label if label in years_ending_in_0 else '' for label in xtick_labels]

ax.set_xticks(xticks)
ax.set_xticklabels(selected_xtick_labels)
plt.xticks(rotation=45)
plt.legend(title='Home Team Goals')
plt.show()

# Visualize distributions for Away Team Goals
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16, 8))
ax = sns.violinplot(x="Year", y="Away Team Goals", data=WorldCupMatches)
ax.set_title('Violin Plots of Away Team Goals for Each Year')
ax.set_xlabel('Year')
ax.set_ylabel('Away Team Goals')

# Adjust the xticks to show only for the years ending in 0
xticks = ax.get_xticks()
xtick_labels = [label.get_text() for label in ax.get_xticklabels()]
selected_xtick_labels = [label if label in years_ending_in_0 else '' for label in xtick_labels]

ax.set_xticks(xticks)
ax.set_xticklabels(selected_xtick_labels)
plt.xticks(rotation=45)
plt.legend(title='Away Team Goals')
plt.show()

# Apply seaborn-white style and re-plot
plt.style.use('seaborn-white')

# Visualize distributions for Home Team Goals with seaborn-white style
plt.figure(figsize=(16, 8))
ax = sns.violinplot(x="Year", y="Home Team Goals", data=WorldCupMatches)
ax.set_title('Violin Plots of Home Team Goals for Each Year (seaborn-white)')
ax.set_xlabel('Year')
ax.set_ylabel('Home Team Goals')

# Adjust the xticks to show only for the years ending in 0
xticks = ax.get_xticks()
xtick_labels = [label.get_text() for label in ax.get_xticklabels()]
selected_xtick_labels = [label if label in years_ending_in_0 else '' for label in xtick_labels]

ax.set_xticks(xticks)
ax.set_xticklabels(selected_xtick_labels)
plt.xticks(rotation=45)
plt.legend(title='Home Team Goals')
plt.show()

# Visualize distributions for Away Team Goals with seaborn-white style
plt.figure(figsize=(16, 8))
ax = sns.violinplot(x="Year", y="Away Team Goals", data=WorldCupMatches)
ax.set_title('Violin Plots of Away Team Goals for Each Year (seaborn-white)')
ax.set_xlabel('Year')
ax.set_ylabel('Away Team Goals')

# Adjust the xticks to show only for the years ending in 0
xticks = ax.get_xticks()
xtick_labels = [label.get_text() for label in ax.get_xticklabels()]
selected_xtick_labels = [label if label in years_ending_in_0 else '' for label in xtick_labels]

ax.set_xticks(xticks)
ax.set_xticklabels(selected_xtick_labels)
plt.xticks(rotation=45)
plt.legend(title='Away Team Goals')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <ipython-input-17-d64b7876647a>:51: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# **Q5** Please use groupby function on Home Team Initials to see the sum of Home Team Goals which can be saved to another data frame by adding .reset_index() end the end of your line.
#
# Then use your new data frame to visualize those total Home Team Goals for your top 5 countries with a bar plot (You can use Home Team Initials). You can use use df.sort_values() function on your data frame by tweaking the ascending option.
#
# Notice that your x-axis will be having country initials, and y-axis will show the total number of Home Team Goals.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/DATA/WorldCupMatches.csv'
WorldCupMatches = pd.read_csv(file_path)

home_team_goals_sum = WorldCupMatches.groupby('Home Team Initials')['Home Team Goals'].sum().reset_index()

top_5_home_team_goals = home_team_goals_sum.sort_values(by='Home Team Goals', ascending=False).head(5)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_5_home_team_goals, x='Home Team Initials', y='Home Team Goals')
plt.title('Top 5 Countries by Total Home Team Goals')
plt.xlabel('Country Initials')
plt.ylabel('Total Home Team Goals')
plt.show()

# %% [markdown]
# **Q6** Please extract the rows for your top 4 countries (Home Team Initials') with the help of the previous question's answer. Then use joyplot again to visualize densities for 'Home Team Goals' and	'Away Team Goals' on the horizantal axis. Notice that your y-axis labels will be your country initials (Home Team Initials'). Make sure that your legend is visible and use 'dark_background' by calling plt.style.use again.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from joypy import joyplot

file_path = '/content/drive/MyDrive/DATA/WorldCupMatches.csv'
WorldCupMatches = pd.read_csv('/content/drive/MyDrive/DATA/WorldCupMatches.csv')

home_team_goals_sum = WorldCupMatches.groupby('Home Team Initials')['Home Team Goals'].sum().reset_index()

top_4_home_team_goals = home_team_goals_sum.sort_values(by='Home Team Goals', ascending=False).head(4)

top_4_countries = top_4_home_team_goals['Home Team Initials'].tolist()
top_4_matches = WorldCupMatches[WorldCupMatches['Home Team Initials'].isin(top_4_countries)]

top_4_matches = top_4_matches[['Home Team Initials', 'Home Team Goals', 'Away Team Goals']]
top_4_matches = pd.melt(top_4_matches, id_vars=['Home Team Initials'], value_vars=['Home Team Goals', 'Away Team Goals'], var_name='Goal Type', value_name='Goals')

plt.style.use('dark_background')

fig, axes = joyplot(
    data=top_4_matches,
    by='Home Team Initials',
    column='Goals',
    kind='kde',
    overlap=1,
    fade=True,
    figsize=(12, 8),
    colormap=plt.cm.viridis,
    legend=True
)

plt.title('Density Plot of Home Team Goals and Away Team Goals for Top 4 Countries')
plt.xlabel('Goals')
plt.ylabel('Country Initials')
plt.show()

# %% [markdown]
# **Q7** Please install seaborn_qqplot as shown below. Then draw a qqplot to compare probability distributions of Home Team Goals and Away Team Goals. Please comment on your finding. Do you think their distributions agree with each other? Please justify your answer by explaining the figure you obtained.

# %%
# !pip install seaborn_qqplot

# %%
from seaborn_qqplot import pplot #seaborn-qqplot is a seaborn extension adding qqplots.
plt.style.use('ggplot') #this is to change the color theme.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from seaborn_qqplot import pplot

file_path = '/content/drive/MyDrive/DATA/WorldCupMatches.csv'
WorldCupMatches = pd.read_csv('/content/drive/MyDrive/DATA/WorldCupMatches.csv')

home_goals = WorldCupMatches['Home Team Goals']
away_goals = WorldCupMatches['Away Team Goals']

plt.figure(figsize=(10, 6))
pplot(data=WorldCupMatches, x='Home Team Goals', y='Away Team Goals', kind='qq', display_kws={"identity":True})
plt.title('QQ Plot Comparing Home Team Goals and Away Team Goals')
plt.xlabel('Home Team Goals Quantiles')
plt.ylabel('Away Team Goals Quantiles')
plt.show()
