# %% [markdown]
# <a href="https://colab.research.google.com/github/lateshapmiller/CSC302_LM/blob/main/Copy_of_FacetGrid_ICA_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *   Please read titanic.csv from the DATA folder
# *   Change 1s to "Survived" under the Survived column of the data frame by looking at the example provided.
# *   Get rows which don't have "?" under Pclass column and move to the next step.

# %%
titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
# Out:
# <ipython-input-4-ec2960f4c8fc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Died' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a multipanel plot which draws density plots for each class-survived combination. Please also use the hue parameter based on the Sex attribute to have two density plots in each panel with different colors.

# %%
#you can uncomment below when you come up with your density plots for each class-survived combination
#titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
#for ax,title in zip(g.axes.flatten(),titles):
#    ax.set_title(title )

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/DATA/titanic.csv'
titanic_data = pd.read_csv(file_path)

titanic_data.info()

titanic_data = titanic_data.dropna(subset=['Age'])

titanic_data['Survived'] = titanic_data['Survived'].astype('category')
titanic_data['Pclass'] = titanic_data['Pclass'].astype('category')

g = sns.FacetGrid(titanic_data, row='Pclass', col='Survived', hue='Sex', margin_titles=True)
g.map(sns.kdeplot, 'Age', common_norm=False)

g.add_legend()
g.set_axis_labels('Age', 'Density')
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Density Plots of Age for Each Class-Survived Combination by Sex')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    object
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
